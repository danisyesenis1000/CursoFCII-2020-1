# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
C = pd.read_csv("datos_circular.csv")
E = dt.read_csv("datos_espiral.csv")
data.head()
# Out:
#          x         y     z
# 0  1.00000  0.000000  0.00
# 1  0.99995  0.010000  0.01
# 2  0.99980  0.019999  0.02
# 3  0.99955  0.029995  0.03
# 4  0.99920  0.039989  0.04

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(data["x"], data["y"], data["z"])
